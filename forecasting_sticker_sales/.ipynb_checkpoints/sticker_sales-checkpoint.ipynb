# %% [markdown]
# # Forecasting Sticker Sales
#
# ## 1. Datasets and EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import utils

df = pd.read_csv(utils.TRAIN_PATH)
df
# Out:
#             id        date    country                 store  \
# 0            0  2010-01-01     Canada     Discount Stickers
# 1            1  2010-01-01     Canada     Discount Stickers
# 2            2  2010-01-01     Canada     Discount Stickers
# 3            3  2010-01-01     Canada     Discount Stickers
# 4            4  2010-01-01     Canada     Discount Stickers
# ...        ...         ...        ...                   ...
# 230125  230125  2016-12-31  Singapore  Premium Sticker Mart
# 230126  230126  2016-12-31  Singapore  Premium Sticker Mart
# 230127  230127  2016-12-31  Singapore  Premium Sticker Mart
# 230128  230128  2016-12-31  Singapore  Premium Sticker Mart
# 230129  230129  2016-12-31  Singapore  Premium Sticker Mart
#
#                    product  num_sold
# 0        Holographic Goose       NaN
# 1                   Kaggle     973.0
# 2             Kaggle Tiers     906.0
# 3                 Kerneler     423.0
# 4       Kerneler Dark Mode     491.0
# ...

# %% [markdown]
# My first thought is that this might be a time-series problem. The evidence is that we have the `date` column spanned from 2010 - 2016. Let see how many distinct dates are there in the datasets.

# %%
df["date"].describe()
# Out:
# count         230130
# unique          2557
# top       2016-12-31
# freq              90
# Name: date, dtype: object

# %%
df.index = pd.to_datetime(df.index)

# %%
print(df["date"].unique().tolist())
# Out:
# ['2010-01-01', '2010-01-02', '2010-01-03', '2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07', '2010-01-08', '2010-01-09', '2010-01-10', '2010-01-11', '2010-01-12', '2010-01-13', '2010-01-14', '2010-01-15', '2010-01-16', '2010-01-17', '2010-01-18', '2010-01-19', '2010-01-20', '2010-01-21', '2010-01-22', '2010-01-23', '2010-01-24', '2010-01-25', '2010-01-26', '2010-01-27', '2010-01-28', '2010-01-29', '2010-01-30', '2010-01-31', '2010-02-01', '2010-02-02', '2010-02-03', '2010-02-04', '2010-02-05', '2010-02-06', '2010-02-07', '2010-02-08', '2010-02-09', '2010-02-10', '2010-02-11', '2010-02-12', '2010-02-13', '2010-02-14', '2010-02-15', '2010-02-16', '2010-02-17', '2010-02-18', '2010-02-19', '2010-02-20', '2010-02-21', '2010-02-22', '2010-02-23', '2010-02-24', '2010-02-25', '2010-02-26', '2010-02-27', '2010-02-28', '2010-03-01', '2010-03-02', '2010-03-03', '2010-03-04', '2010-03-05', '2010-03-06', '2010-03-07', '2010-03-08', '2010-03-09', '2010-03-10', '2010-03-11', '2010-03-12', '20
# ...

# %%
df["date"].value_counts()
# Out:
# date
# 2016-12-31    90
# 2010-01-01    90
# 2010-01-02    90
# 2010-01-03    90
# 2010-01-04    90
#               ..
# 2010-02-02    90
# 2010-02-03    90
# 2010-02-04    90
# 2010-02-05    90
# 2010-02-06    90
# Name: count, Length: 2557, dtype: int64

# %% [markdown]
# It seems like our dataset is recorded daily at frequency of 90 records per day.

# %%
df["country"].value_counts()
# Out:
# country
# Canada       38355
# Finland      38355
# Italy        38355
# Kenya        38355
# Norway       38355
# Singapore    38355
# Name: count, dtype: int64

# %%
df["store"].value_counts()
# Out:
# store
# Discount Stickers       76710
# Stickers for Less       76710
# Premium Sticker Mart    76710
# Name: count, dtype: int64

# %%
df["product"].value_counts()
# Out:
# product
# Holographic Goose     46026
# Kaggle                46026
# Kaggle Tiers          46026
# Kerneler              46026
# Kerneler Dark Mode    46026
# Name: count, dtype: int64

# %%
df["num_sold"].hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# So the dataset is recorded daily with: `5 products` $\times$ `3 stores` $\times$ `6 countries` = `90 records`
# Our task is to predict `num_sold` columns. There are some approaches here I could think of:
# 1. Basic ML models, with `store` included as a feature column.
# 2. Build 3 seperated time-series models for each store (this has more potential)
# 3. But based on the second bullet points above, I can totally build 90 models for each type of product in each store and in each country. Each model is now a very simple time-series model.
#
# In this project, I will try method 2 and 3. But first, let us try with one specific situations here.

# %%
canada_premium_kaggle = df[df["country"] == "Canada"]
canada_premium_kaggle = canada_premium_kaggle[canada_premium_kaggle["store"] == "Premium Sticker Mart"]
canada_premium_kaggle = canada_premium_kaggle[canada_premium_kaggle["product"] == "Kaggle"]
canada_premium_kaggle
# Out:
#                                    id        date country  \
# 1970-01-01 00:00:00.000000011      11  2010-01-01  Canada
# 1970-01-01 00:00:00.000000101     101  2010-01-02  Canada
# 1970-01-01 00:00:00.000000191     191  2010-01-03  Canada
# 1970-01-01 00:00:00.000000281     281  2010-01-04  Canada
# 1970-01-01 00:00:00.000000371     371  2010-01-05  Canada
# ...                               ...         ...     ...
# 1970-01-01 00:00:00.000229691  229691  2016-12-27  Canada
# 1970-01-01 00:00:00.000229781  229781  2016-12-28  Canada
# 1970-01-01 00:00:00.000229871  229871  2016-12-29  Canada
# 1970-01-01 00:00:00.000229961  229961  2016-12-30  Canada
# 1970-01-01 00:00:00.000230051  230051  2016-12-31  Canada
#
#                                               store product  num_sold
# 1970-01-01 00:00:00.000000011  Premium Sticker Mart  Kaggle    2212.0
# 1970-01-01 00:00:00.000000101  Premium Sticker Mart  Kaggle    2183.0
# ...

# %% [markdown]
# The series looks like it has some pattern every year.

# %%
plt.figure(figsize=(20, 5))
plt.plot(canada_premium_kaggle["num_sold"])
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

adf_test = adfuller(canada_premium_kaggle["num_sold"])
print(f"ADF Statistic: {adf_test[0]}")
print(f"P-value: {adf_test[1]}")
# Out:
# ADF Statistic: -2.2339813849213765
# P-value: 0.19414409063997923

# %% [markdown]
# `p-value` is larger than 0.05, so the time series is **not stationary**. We will try to differentiate it to make it stationary.

# %%
canada_premium_kaggle["num_sold_diff"] = canada_premium_kaggle["num_sold"].diff()
canada_premium_kaggle.dropna(inplace=True)

plt.figure(figsize=(20, 5))
plt.plot(canada_premium_kaggle["num_sold_diff"])
plt.show()

# %%
adf_test = adfuller(canada_premium_kaggle["num_sold_diff"])
print(f"ADF Statistic: {adf_test[0]}")
print(f"P-value: {adf_test[1]}")
# Out:
# ADF Statistic: -14.013419254665472
# P-value: 3.6789718207083876e-26

# %%
canada_premium_kaggle.count()
# Out:
# id               2556
# date             2556
# country          2556
# store            2556
# product          2556
# num_sold         2556
# num_sold_diff    2556
# dtype: int64

# %% [markdown]
# The series is **stationary** now. Let's try fitting a SARIMA model.

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

model = SARIMAX(canada_premium_kaggle["num_sold"], order=(1, 0, 1), seasonal_order=(1, 0, 1, 7))

model_fit = model.fit()
model_fit.summary()
# Out:
# /home/m1nhd3n/Works/AI/.venv/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency 90ns will be used.
#   self._init_dates(dates, freq)
# /home/m1nhd3n/Works/AI/.venv/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency 90ns will be used.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                          num_sold   No. Observations:                 2556
# Model:             SARIMAX(1, 0, 1)x(1, 0, 1, 7)   Log Likelihood              -15465.639
# Date:                           Thu, 27 Feb 2025   AIC                          30941.277
# Time:                                   12:27:08   BIC                          30970.508
# ...

# %%
# Forecast next 30 days
forecast = model_fit.get_forecast(steps=30)

# Create a date index starting from the last date in the dataset
forecast_index = pd.date_range(start=df.index[-1], periods=30, freq="D")

# Convert forecast predictions to a pandas Series
forecast_series = pd.Series(forecast.predicted_mean.values, index=forecast_index)

# Plot actual vs. forecast
plt.figure(figsize=(15, 5))
# plt.plot(diff_can, label="Observed", color="blue")
plt.plot(forecast_series, label="Forecast", color="red", linestyle="dashed")
plt.legend()
plt.title("Time Series Forecast")
plt.show()
